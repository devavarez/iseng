# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('vgsales.csv')

# %%
df
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16598 non-null  int64
#  1   Name          16598 non-null  object
#  2   Platform      16598 non-null  object
#  3   Year          16327 non-null  float64
#  4   Genre         16598 non-null  object
#  5   Publisher     16540 non-null  object
#  6   NA_Sales      16598 non-null  float64
#  7   EU_Sales      16598 non-null  float64
#  8   JP_Sales      16598 non-null  float64
#  9   Other_Sales   16598 non-null  float64
#  10  Global_Sales  16598 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB

# %%
con_y = df['Year'].isnull()
df[con_y]
# Out:
#         Rank                         Name Platform  Year         Genre  \
# 179      180              Madden NFL 2004      PS2   NaN        Sports
# 377      378             FIFA Soccer 2004      PS2   NaN        Sports
# 431      432   LEGO Batman: The Videogame      Wii   NaN        Action
# 470      471   wwe Smackdown vs. Raw 2006      PS2   NaN      Fighting
# 607      608               Space Invaders     2600   NaN       Shooter
# ...      ...                          ...      ...   ...           ...
# 16307  16310                Freaky Flyers       GC   NaN        Racing
# 16327  16330                    Inversion       PC   NaN       Shooter
# 16366  16369  Hakuouki: Shinsengumi Kitan      PS3   NaN     Adventure
# 16427  16430                 Virtua Quest       GC   NaN  Role-Playing
# 16493  16496                   The Smurfs      3DS   NaN        Action
#
#                                     Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
df_new = df[~con_y]
df_new
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
df_copy = df_new.copy()
df_copy['Year'] = pd.to_datetime(df_copy['Year'], format='%Y', errors='coerce')
df_copy['Year'] = df_copy['Year'].dt.year
df_new = df_copy
df_new
# Out:
#         Rank                                              Name Platform  Year  \
# 0          1                                        Wii Sports      Wii  2006
# 1          2                                 Super Mario Bros.      NES  1985
# 2          3                                    Mario Kart Wii      Wii  2008
# 3          4                                 Wii Sports Resort      Wii  2009
# 4          5                          Pokemon Red/Pokemon Blue       GB  1996
# ...      ...                                               ...      ...   ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA  2002
# 16594  16597                     Men in Black II: Alien Escape       GC  2003
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2  2008
# 16596  16599                                        Know How 2       DS  2010
# 16597  16600                                  Spirits & Spells      GBA  2003
#
# ...

# %%
df_new = df_new[(df_new['Year']>= 2010) & (df_new['Year']<=2015)]
df_new
# Out:
#         Rank                                        Name Platform  Year  \
# 15        16                          Kinect Adventures!     X360  2010
# 16        17                          Grand Theft Auto V      PS3  2013
# 23        24                          Grand Theft Auto V     X360  2013
# 26        27                 Pokemon Black/Pokemon White       DS  2010
# 29        30              Call of Duty: Modern Warfare 3     X360  2011
# ...      ...                                         ...      ...   ...
# 16571  16574  Grisaia no Kajitsu: La Fruit de la Grisaia      PSP  2013
# 16578  16581               Outdoors Unleashed: Africa 3D      3DS  2011
# 16581  16584                                   Fit & Fun      Wii  2011
# 16585  16588                                      Breach       PC  2011
# 16596  16599                                  Know How 2       DS  2010
#
#               Genre               Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
con_null = df_new['Publisher'].isnull()
con_un = df_new['Publisher'] == 'Unknown'
df_new[con_null & con_un]
# Out:
# Empty DataFrame
# Columns: [Rank, Name, Platform, Year, Genre, Publisher, NA_Sales, EU_Sales, JP_Sales, Other_Sales, Global_Sales]
# Index: []

# %%
df_new = df_new[~con_null & ~con_un]
df_new
# Out:
#         Rank                                               Name Platform  \
# 15        16                                 Kinect Adventures!     X360
# 16        17                                 Grand Theft Auto V      PS3
# 23        24                                 Grand Theft Auto V     X360
# 26        27                        Pokemon Black/Pokemon White       DS
# 29        30                     Call of Duty: Modern Warfare 3     X360
# ...      ...                                                ...      ...
# 16567  16570  Fujiko F. Fujio Characters: Great Assembly! Sl...      3DS
# 16571  16574         Grisaia no Kajitsu: La Fruit de la Grisaia      PSP
# 16578  16581                      Outdoors Unleashed: Africa 3D      3DS
# 16585  16588                                             Breach       PC
# 16596  16599                                         Know How 2       DS
#
#        Year         Genre               Publisher  NA_Sales  EU_Sales  \
# ...

# %%
df_fin = df_new.groupby(['Publisher', 'Year'])[['Global_Sales', 'NA_Sales']].sum().reset_index()
df_fin
# Out:
#                 Publisher  Year  Global_Sales  NA_Sales
# 0              1C Company  2011          0.09      0.01
# 1               505 Games  2010         14.26      8.50
# 2               505 Games  2011          3.30      1.98
# 3               505 Games  2012          2.34      0.89
# 4               505 Games  2013          2.31      1.00
# ..                    ...   ...           ...       ...
# 586       dramatic create  2015          0.08      0.00
# 587                  iWin  2011          0.06      0.00
# 588       imageepoch Inc.  2014          0.04      0.00
# 589  inXile Entertainment  2015          0.10      0.02
# 590             mixi, Inc  2015          0.86      0.00
#
# [591 rows x 4 columns]

# %%
year_sum = df_fin.groupby('Year')['Global_Sales', 'NA_Sales'].sum().reset_index()
year_sum
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_6820\19276933.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   year_sum = df_fin.groupby('Year')['Global_Sales', 'NA_Sales'].sum().reset_index()
#    Year  Global_Sales  NA_Sales
# 0  2010        598.49    303.50
# 1  2011        511.01    239.21
# 2  2012        363.17    154.89
# 3  2013        368.05    154.77
# 4  2014        336.65    131.75
# 5  2015        264.34    102.82

# %%
con_test = df_fin['Publisher'] == 'Take-Two Interactive' #buat nyari publisher mana yg datanya ada dari 2010-2015 buat perbandingan
df_fin[con_test]
# Out:
#                 Publisher  Year  Global_Sales  NA_Sales
# 517  Take-Two Interactive  2010         35.84     20.82
# 518  Take-Two Interactive  2011         18.03     11.25
# 519  Take-Two Interactive  2012         21.58     12.70
# 520  Take-Two Interactive  2013         52.41     25.87
# 521  Take-Two Interactive  2014         30.26     14.23
# 522  Take-Two Interactive  2015         15.03      8.58

# %%
select_pubs = df_fin.nlargest(10, 'Global_Sales')
df_select = df_fin[df_fin['Publisher'].isin(select_pubs['Publisher'])].reset_index()
df_select
# Out:
#     index             Publisher  Year  Global_Sales  NA_Sales
# 0      26            Activision  2010         63.39     39.49
# 1      27            Activision  2011         51.74     28.97
# 2      28            Activision  2012         53.25     26.37
# 3      29            Activision  2013         43.49     23.25
# 4      30            Activision  2014         44.48     21.55
# 5      31            Activision  2015         35.63     16.95
# 6     182       Electronic Arts  2010         81.38     39.24
# 7     183       Electronic Arts  2011         72.25     33.42
# 8     184       Electronic Arts  2012         49.90     20.80
# 9     185       Electronic Arts  2013         52.92     22.18
# 10    186       Electronic Arts  2014         46.80     18.81
# 11    187       Electronic Arts  2015         45.42     17.62
# 12    377              Nintendo  2010         61.07     24.18
# 13    378              Nintendo  2011         51.53     20.24
# ...

# %%
df_fin['Publisher_groups']= df_fin['Publisher'].apply(lambda x:x if x in select_pubs else 'Others')
df_fin
# Out:
#                 Publisher  Year  Global_Sales  NA_Sales Publisher_groups
# 0              1C Company  2011          0.09      0.01           Others
# 1               505 Games  2010         14.26      8.50           Others
# 2               505 Games  2011          3.30      1.98           Others
# 3               505 Games  2012          2.34      0.89           Others
# 4               505 Games  2013          2.31      1.00           Others
# ..                    ...   ...           ...       ...              ...
# 586       dramatic create  2015          0.08      0.00           Others
# 587                  iWin  2011          0.06      0.00           Others
# 588       imageepoch Inc.  2014          0.04      0.00           Others
# 589  inXile Entertainment  2015          0.10      0.02           Others
# 590             mixi, Inc  2015          0.86      0.00           Others
#
# [591 rows x 5 columns]

# %%
plt.bar(year_sum['Year'], year_sum['Global_Sales'], alpha= 0.5, color= 'grey', label= 'Others')
plt.bar(df_select['Year'], df_select['Global_Sales'], alpha= 0.5)

color_maps = plt.colormaps['tab10']

for i, pubs in enumerate(df_select['Publisher'].unique()):
    subset = df_select[df_select['Publisher'] == pubs]
    plt.bar(subset['Year'], subset['Global_Sales'], color= color_maps(i), label= f'Publisher: {pubs}', linewidth=200)
    

plt.xlabel('Year', labelpad= 10, size= 14)
plt.ylabel('Global Sales(in million)', labelpad= 10, size= 14)
plt.title('Penjualan Video Game dari tahun 2010 hingga 2015')
plt.legend(loc='right', bbox_to_anchor=(1.6, 0.5))
plt.show()

# %%
plt.bar(df_select['Year'], df_select['Global_Sales'], alpha= 0.5)

color_maps = plt.colormaps['tab10']

for i, pubs in enumerate(df_select['Publisher'].unique()):
    subset = df_select[df_select['Publisher'] == pubs]
    plt.bar(subset['Year'], subset['Global_Sales'], color= color_maps(i), alpha= 1, label= f'Publisher: {pubs}')
    if pubs == 'Activision':
        plt.plot(subset['Year'], subset['Global_Sales'], color='blue', label= f'Publisher: {pubs}', marker= 'o')
    else:
        plt.bar(subset['Year'], subset['Global_Sales'], color= color_maps(i), label= f'Publisher: {pubs}')

    
    
plt.xlabel('Year', labelpad= 10, size= 14)
plt.ylabel('Global Sales(in million)', labelpad= 10, size= 14)
plt.title('Penjualan Video Game dari tahun 2010 hingga 2015')
plt.legend(loc='right', bbox_to_anchor=(1.6, 0.5))
plt.show()

# %%
con_Pubs = df_select['Publisher'].unique()
con_Years= df_fin['Year'] == 2010

df_2010 = df_fin[con_Years]

top_publisher= df_2010['Publisher'].value_counts().nlargest(10).index
df_2010['Publisher_group'] = df_2010['Publisher'].apply(lambda x: x if x in top_publisher else 'Others')

sum_2010 = df_2010.groupby('Publisher_group')['Global_Sales'].sum()

plt.pie(sum_2010, labels= sum_2010.index, autopct= '%1.1f%%', startangle= 360 )
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_12284\1388389016.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2010['Publisher_group'] = df_2010['Publisher'].apply(lambda x: x if x in top_publisher else 'Others')
# ([<matplotlib.patches.Wedge at 0x218351ee690>,
# ...
#  [Text(1.0969197579426921, 0.0822620485700777, '505 Games'),
#   Text(1.0875407807622057, 0.16509103603506836, 'Neko Entertainment'),
#   Text(1.0873581349850985, 0.16628976601621712, 'Nexon'),
#   Text(0.9794864778890491, 0.5006058725509575, 'Nintendo'),
#   Text(0.7674711417933244, 0.7880279478003627, 'Nippon Ichi Software'),
#   Text(0.7624921316530592, 0.7928466113739618, 'Nobilis'),
#   Text(0.7614510232145618, 0.7938465464090002, 'Nordcurrent'),
# ...

# %%
# Out:
#         Rank                                               Name Platform  \
# 29        30                     Call of Duty: Modern Warfare 3     X360
# 31        32                            Call of Duty: Black Ops     X360
# 33        34                          Call of Duty: Black Ops 3      PS4
# 34        35                         Call of Duty: Black Ops II      PS3
# 35        36                         Call of Duty: Black Ops II     X360
# ...      ...                                                ...      ...
# 15859  15862                                Transformers: Prime      Wii
# 16406  16409                    The Amazing Spider-Man 2 (2014)       PC
# 16411  16414                 Teenage Mutant Ninja Turtles (3DS)      3DS
# 16501  16504  Transformers: War for Cybertron (XBox 360, PS3...       PC
# 16537  16540                    Transformers: Fall of Cybertron       PC
#
#        Year    Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# ...
